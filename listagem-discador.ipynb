# %%
import glob
import pandas as pd
import xlrd
from openpyxl import Workbook

lista_arquivo = []
for arquivo in glob.glob(r"M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\*xls"):
    lista_arquivo.append(arquivo)

# Salvando Blacklist

df = pd.read_excel(r'M:\Atendimento\Oferta Ativa\MK Bairros\Importante\01 - Contatos excluídos.xlsx', sheet_name='Blacklist')

def lista_blacklist(nome_coluna, data_frame):
    valores_coluna = data_frame[nome_coluna]
    valores_coluna = valores_coluna.dropna()
    valores_coluna = valores_coluna.apply(str)

    blacklist = []
    for i in valores_coluna:
        l = i.replace('.0', '')
        if l != '0':
            blacklist.append(l)
    
    return blacklist

coluna1 = lista_blacklist('Tel 1', df)
coluna2 = lista_blacklist('Tel 2', df)
coluna3 = lista_blacklist('Tel 3', df)
coluna4 = lista_blacklist('Tel 4', df)
coluna5 = lista_blacklist('Cel1', df)

headhunter = coluna1 + coluna2 + coluna3 + coluna4 + coluna5

def excluir_linhas_excel(arquivo_entrada, arquivo_saida, lista_exclusao):
    # Abrir o arquivo Excel com xlrd
    workbook = xlrd.open_workbook(arquivo_entrada)
    sheet = workbook.sheet_by_index(0)

    # Criar uma nova planilha para salvar as modificações com openpyxl
    wb = Workbook()
    ws = wb.active

    # Lista para manter o índice das linhas a serem excluídas
    linhas_excluir = set()

    # Identificar as linhas a serem excluídas
    for row_index in range(sheet.nrows):
        row = sheet.row_values(row_index)
        if any(item in row for item in lista_exclusao):
            linhas_excluir.add(row_index)

    # Escrever as linhas não excluídas na nova planilha
    for row_index in range(sheet.nrows):
        if row_index not in linhas_excluir:
            row_values = sheet.row_values(row_index)
            ws.append(row_values)

    # Salvar as modificações
    wb.save(arquivo_saida)

for i in lista_arquivo:
    arquivo_entrada = i
    nome_arquivo = i.replace('M:\\Atendimento\\Oferta Ativa\\MK Bairros\\Bases Bairros\\2024\\', '')
    arquivo_saida = f'M:\\Atendimento\\Oferta Ativa\\MK Bairros\\Bases Bairros\\2024\\Base Discador Convertida\\{nome_arquivo}.xlsx'
    lista_exclusao = headhunter

    excluir_linhas_excel(arquivo_entrada, arquivo_saida, lista_exclusao)
    print(f"Arquivo {nome_arquivo} Final criado.")

#Lista de arquivos
lista_arquivoxlsx = glob.glob(r"M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\*.xlsx")

# Iterate over each Excel file
for i in lista_arquivoxlsx:
   
    excel = pd.read_excel(i)
    telefones_df_new = pd.DataFrame(excel, columns=['Tel 1', 'Tel 2', 'Tel 3', 'Tel 4', 'Cel1', 'Cel2', 'Nome', 'Bairro', 'Email'])
    telefones_organizados_new = telefones_df_new.melt(id_vars=['Nome', 'Bairro', 'Email'], 
                                           value_vars=['Tel 1', 'Tel 2', 'Tel 3', 'Tel 4', 'Cel1', 'Cel2'], 
                                           var_name='Phone_Type', 
                                           value_name='Phone')
    telefones_organizados_new = telefones_organizados_new.dropna(subset=['Phone'])
    telefones_organizados_new = telefones_organizados_new[telefones_organizados_new['Phone'] != 0]
    telefones_organizados_new = telefones_organizados_new.drop(columns=['Phone_Type'])
    output_file_path_new = f'M:\\Atendimento\\Oferta Ativa\\MK Bairros\\Bases Bairros\\2024\\Base Discador Convertida\\Base Discador Final\\{i.split("\\")[-1]}'
    telefones_organizados_new.to_excel(output_file_path_new, index=False)

    print(f"{i} -> Completo")
# Out:
# Arquivo Anil 2024.xls Final criado.
# Arquivo Barra da Tijuca 2024.xls Final criado.
# Arquivo Barra da Tijuca AA 2024.xls Final criado.
# Arquivo Botafogo 2024.xls Final criado.
# Arquivo Botafogo AA 2024.xls Final criado.
# Arquivo Cachambi 2024.xls Final criado.
# Arquivo Camorim 2024.xls Final criado.
# Arquivo Campo Grande F 2024.xls Final criado.
# Arquivo Campo Grande M 2024.xls Final criado.
# Arquivo Catete 2024.xls Final criado.
# Arquivo Centro 2024.xls Final criado.
# Arquivo Copacabana 2024.xls Final criado.
# Arquivo Cosme Velho 2024.xls Final criado.
# Arquivo Duque de Caxias F 2024.xls Final criado.
# Arquivo Duque de Caxias M 2024.xls Final criado.
# Arquivo Flamengo 2024.xls Final criado.
# Arquivo Flamengo AA 2024.xls Final criado.
# Arquivo Freguesia JPA 2024.xls Final criado.
# Arquivo Gavea 2024.xls Final criado.
# Arquivo Gavea AA 2024.xls Final criado.
# Arquivo Gloria 2024.xls Final criado.
# Arquivo Humaita 2024.xls Final criado.
# Arquivo Humaita AA 2024.xls Final criado.
# Arquivo Ipanema 2024.xls Final criado.
# Arquivo jacarepagua 2024.xls Final criado.
# Arquivo Jd botanico 2024.xls Final criado.
# Arquivo JD Guanabara 2024.xls Final criado.
# Arquivo JD Sulacap 2024.xls Final criado.
# Arquivo Joa 2024.xls Final criado.
# Arquivo Lagoa 2024.xls Final criado.
# Arquivo Laranjeiras 2024.xls Final criado.
# Arquivo Leblon 2024.xls Final criado.
# Arquivo Meier 2024.xls Final criado.
# Arquivo Mutondo 2024.xls Final criado.
# Arquivo Nova Iguacu pt01 2024.xls Final criado.
# Arquivo Nova Iguacu pt02 2024.xls Final criado.
# Arquivo Nova Iguacu pt03 2024.xls Final criado.
# Arquivo Nova Iguacu pt04 2024.xls Final criado.
# Arquivo Pechincha 2024.xls Final criado.
# Arquivo Praça Seca 2024.xls Final criado.
# Arquivo Recreio dos Bandeirantes 2024.xls Final criado.
# Arquivo Riachuelo 2024.xls Final criado.
# Arquivo Sao Conrado 2024.xls Final criado.
# Arquivo Saude 2024.xls Final criado.
# Arquivo Tijuca_2024.xls Final criado.
# Arquivo Urca 2024.xls Final criado.
# Arquivo Vargem Grande 2024.xls Final criado.
# Arquivo Vargem Pequena 2024.xls Final criado.
# Arquivo Vila da Penha AA 2024.xls Final criado.
# Arquivo Vl da Penha 2024.xls Final criado.
# Arquivo VL VALQUEIRE 2024.xls Final criado.
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Anil 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Barra da Tijuca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Barra da Tijuca AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Botafogo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Botafogo AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Cachambi 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Camorim 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Campo Grande F 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Campo Grande M 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Catete 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Centro 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Copacabana 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Cosme Velho 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Duque de Caxias F 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Duque de Caxias M 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Flamengo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Flamengo AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Freguesia JPA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gavea 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gavea AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gloria 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Humaita 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Humaita AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Ipanema 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\jacarepagua 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Jd botanico 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\JD Guanabara 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\JD Sulacap 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Joa 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Lagoa 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Laranjeiras 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Leblon 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Meier 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Mutondo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt01 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt02 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt03 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt04 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Pechincha 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Praça Seca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Recreio dos Bandeirantes 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Riachuelo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Sao Conrado 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Saude 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Tijuca_2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Urca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vargem Grande 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vargem Pequena 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vila da Penha AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vl da Penha 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\VL VALQUEIRE 2024.xls.xlsx -> Completed

# %%
import pandas as pd
import glob

# Create a list of Excel file paths
lista_arquivoxlsx = glob.glob(r"M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\*.xlsx")

# Iterate over each Excel file
for i in lista_arquivoxlsx:
    # Read Excel file into a DataFrame
    excel = pd.read_excel(i)
    
    # Create DataFrame with specific columns
    phones_df_new = pd.DataFrame(excel, columns=['Tel 1', 'Tel 2', 'Tel 3', 'Tel 4', 'Cel1', 'Cel2', 'Nome', 'Bairro', 'Email'])
    
    # Melt DataFrame
    phones_melted_new = phones_df_new.melt(id_vars=['Nome', 'Bairro', 'Email'], 
                                           value_vars=['Tel 1', 'Tel 2', 'Tel 3', 'Tel 4', 'Cel1', 'Cel2'], 
                                           var_name='Phone_Type', 
                                           value_name='Phone')
    
    # Clean up melted DataFrame
    phones_melted_new = phones_melted_new.dropna(subset=['Phone'])  # Drop rows where 'Phone' is NaN
    phones_melted_new = phones_melted_new[phones_melted_new['Phone'] != 0]  # Adjust as needed based on your data
    
    # Drop the 'Phone_Type' column if it's not needed
    phones_melted_new = phones_melted_new.drop(columns=['Phone_Type'])
    
    # Construct output file path based on input file name
    output_file_path_new = f'M:\\Atendimento\\Oferta Ativa\\MK Bairros\\Bases Bairros\\2024\\Base Discador Convertida\\Base Discador Final\\{i.split("\\")[-1]}'
    
    # Write melted DataFrame to Excel
    phones_melted_new.to_excel(output_file_path_new, index=False)

    print(f"Processed file: {i} -> Completed")
# Out:
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Anil 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Barra da Tijuca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Barra da Tijuca AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Botafogo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Botafogo AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Cachambi 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Camorim 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Campo Grande F 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Campo Grande M 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Catete 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Centro 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Copacabana 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Cosme Velho 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Duque de Caxias F 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Duque de Caxias M 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Flamengo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Flamengo AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Freguesia JPA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gavea 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gavea AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Gloria 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Humaita 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Humaita AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Ipanema 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\jacarepagua 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Jd botanico 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\JD Guanabara 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\JD Sulacap 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Joa 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Lagoa 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Laranjeiras 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Leblon 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Meier 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Mutondo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt01 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt02 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt03 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Nova Iguacu pt04 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Pechincha 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Praça Seca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Recreio dos Bandeirantes 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Riachuelo 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Sao Conrado 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Saude 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Tijuca_2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Urca 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vargem Grande 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vargem Pequena 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vila da Penha AA 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\Vl da Penha 2024.xls.xlsx -> Completed
# Processed file: M:\Atendimento\Oferta Ativa\MK Bairros\Bases Bairros\2024\Base Discador Convertida\VL VALQUEIRE 2024.xls.xlsx -> Completed
